# %% [markdown]
# #### import corresponding libraries

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# #### Loading Data

# %%
df = pd.read_excel('data.xlsx')
df
# Out:
#      num_preg  glucose_conc  diastolic_bp  thickness  insulin   bmi  \
# 0           6           148            72         35        0  33.6
# 1           1            85            66         29        0  26.6
# 2           8           183            64          0        0  23.3
# 3           1            89            66         23       94  28.1
# 4           0           137            40         35      168  43.1
# ..        ...           ...           ...        ...      ...   ...
# 763        10           101            76         48      180  32.9
# 764         2           122            70         27        0  36.8
# 765         5           121            72         23      112  26.2
# 766         1           126            60          0        0  30.1
# 767         1            93            70         31        0  30.4
#
#      diab_pred  age  diabetes_orig    skin  has_diabetes  diabetes
# 0        0.627   50              1  1.3790          True      True
# ...

# %%
pd.set_option('display.max_rows',None)
df
# Out:
#      num_preg  glucose_conc  diastolic_bp  thickness  insulin   bmi  \
# 0           6           148            72         35        0  33.6
# 1           1            85            66         29        0  26.6
# 2           8           183            64          0        0  23.3
# 3           1            89            66         23       94  28.1
# 4           0           137            40         35      168  43.1
# 5           5           116            74          0        0  25.6
# 6           3            78            50         32       88  31.0
# 7          10           115             0          0        0  35.3
# 8           2           197            70         45      543  30.5
# 9           8           125            96          0        0   0.0
# 10          4           110            92          0        0  37.6
# 11         10           168            74          0        0  38.0
# 12         10           139            80          0        0  27.1
# ...

# %%
df.columns
# Out:
# Index(['num_preg', 'glucose_conc', 'diastolic_bp', 'thickness', 'insulin',
#        'bmi', 'diab_pred', 'age', 'diabetes_orig', 'skin', 'has_diabetes',
#        'diabetes'],
#       dtype='object')

# %%
df.shape
# Out:
# (768, 12)

# %% [markdown]
# #### Cleaning the data i.e., finding null values present in data set or not, if present replace them with valid data using --> dropna, fillna

# %%
df.isnull()
# Out:
#      num_preg  glucose_conc  diastolic_bp  thickness  insulin    bmi  \
# 0       False         False         False      False    False  False
# 1       False         False         False      False    False  False
# 2       False         False         False      False    False  False
# 3       False         False         False      False    False  False
# 4       False         False         False      False    False  False
# 5       False         False         False      False    False  False
# 6       False         False         False      False    False  False
# 7       False         False         False      False    False  False
# 8       False         False         False      False    False  False
# 9       False         False         False      False    False  False
# 10      False         False         False      False    False  False
# 11      False         False         False      False    False  False
# 12      False         False         False      False    False  False
# ...

# %%
df.isnull().values.any()
# Out:
# np.False_

# %%
df.isnull().sum()
# Out:
# num_preg         0
# glucose_conc     0
# diastolic_bp     0
# thickness        0
# insulin          0
# bmi              0
# diab_pred        0
# age              0
# diabetes_orig    0
# skin             0
# has_diabetes     0
# diabetes         0
# dtype: int64

# %% [markdown]
# #### Finding correlation between columns

# %%
corr = df.corr()
fig,ax= plt.subplots(figsize=(12,12))
cmap = 'plasma'
ax.matshow(corr,cmap=cmap)
plt.xticks(range(len(corr.columns)),corr.columns,rotation=90)
plt.yticks(range(len(corr.columns)),corr.columns)
plt.grid()
plt.show()

# %% [markdown]
# #### thickness vs skin;
# #### diabetes_orig vs has_diabetes;
# #### diabetes_orig vs diabetes;
# #### has_diabetes vs diabetes;
# #### above all are correlated with each other --> drop any one of those 2 correlated.

# %%
df.drop('thickness',axis=1,inplace=True)
df.drop('has_diabetes',axis=1,inplace=True)
df.drop('diabetes_orig',axis=1,inplace=True)

# %%
corr = df.corr()
fig,ax= plt.subplots(figsize=(12,12))
cmap = 'plasma'
ax.matshow(corr,cmap=cmap)
plt.xticks(range(len(corr.columns)),corr.columns,rotation=90)
plt.yticks(range(len(corr.columns)),corr.columns)
plt.grid()
plt.show()

# %%
df.head()
# Out:
#    num_preg  glucose_conc  diastolic_bp  insulin   bmi  diab_pred  age  \
# 0         6           148            72        0  33.6      0.627   50
# 1         1            85            66        0  26.6      0.351   31
# 2         8           183            64        0  23.3      0.672   32
# 3         1            89            66       94  28.1      0.167   21
# 4         0           137            40      168  43.1      2.288   33
#
#      skin  diabetes
# 0  1.3790      True
# 1  1.1426     False
# 2  0.0000      True
# 3  0.9062     False
# 4  1.3790      True

# %% [markdown]
# #### Check for string data in table and replace it with integer type/boolean type

# %%
# Creating a dictionary to convert True to 1 and False to 0
# Want to replace True and false in diabetes columns
dict1 = {'diabetes':[True,False]}
dict2 = {'diabetes':[1,0]}

# %%
df.replace(dict1, dict2, inplace=True)
# Out:
# C:\Users\sudha\AppData\Local\Temp\ipykernel_5368\2313552751.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace(dict1, dict2, inplace=True)

# %%
df
# Out:
#      num_preg  glucose_conc  diastolic_bp  insulin   bmi  diab_pred  age  \
# 0           6           148            72        0  33.6      0.627   50
# 1           1            85            66        0  26.6      0.351   31
# 2           8           183            64        0  23.3      0.672   32
# 3           1            89            66       94  28.1      0.167   21
# 4           0           137            40      168  43.1      2.288   33
# 5           5           116            74        0  25.6      0.201   30
# 6           3            78            50       88  31.0      0.248   26
# 7          10           115             0        0  35.3      0.134   29
# 8           2           197            70      543  30.5      0.158   53
# 9           8           125            96        0   0.0      0.232   54
# 10          4           110            92        0  37.6      0.191   30
# 11         10           168            74        0  38.0      0.537   34
# ...

# %% [markdown]
# #### Checking the percentage of Data is True & False

# %%
num_true = len(df.loc[df['diabetes']==1])
num_false = len(df.loc[df['diabetes'] == 0])
print(f'num_true = {num_true}')
print(f'num_false = {num_false}')
per_num_true = (num_true / (num_true+num_false))*100
print(per_num_true)
per_num_false = (num_false/(num_false+num_true))*100
print(per_num_false)
# Out:
# num_true = 268
# num_false = 500
# 34.89583333333333
# 65.10416666666666

# %% [markdown]
# #### Splitting the data for Training and Testing the model

# %%
from sklearn.model_selection import train_test_split
input_columns = ['num_preg','glucose_conc','diastolic_bp','insulin','bmi','diab_pred','age','skin']
output_columns = ['diabetes']
x = df[input_columns].values
y = df[output_columns].values
spilt_test_size = 0.3
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = spilt_test_size,random_state=42)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (537, 8)
# (537, 1)
# (231, 8)
# (231, 1)

# %%
print('{0:0.2f}% in training set'.format((len(x_train)/len(df.index))*100))
print('{0:0.2f}% in testing set'.format((len(x_test)/len(df.index))*100))
# Out:
# 69.92% in training set
# 30.08% in testing set

# %%
print('training true:{0} ({1:0.2f}%)'.format(len(y_train[y_train[ :,0 ] == 1]),len(y_train[y_train[ :,0 ] ==
 1])/len(y_train) * 100))
print('training False:{0} ({1:0.2f}%)'.format(len(y_train[y_train[ :, 0] == 0]),len(y_train[y_train[ :,0 ] ==
 0])/len(y_train) * 100))
print('Test true:{0} ({1:0.2f}%)'.format(len(y_test[y_test[ :,0 ] == 1]),len(y_test[y_test[ :,0 ] ==
 1])/len(y_test) * 100))
print('Test false:{0} ({1:0.2f}%)'.format(len(y_test[y_test[ :,0 ] == 0]),len(y_test[y_test[ :,0 ] ==
 0])/len(y_test) * 100))
# Out:
# training true:188 (35.01%)
# training False:349 (64.99%)
# Test true:80 (34.63%)
# Test false:151 (65.37%)

# %% [markdown]
# #### Validating the trained and tested data, i.e., replacing NULL data with meaningful values

# %%
total_num_preg = len(df.loc[df['num_preg']== 0])
print(f'number of Rows missing in num_preg column is {total_num_preg}')
total_glucose_conc = len(df.loc[df['glucose_conc']==0])
print(f'number of Rows missing in glucose_conc column is {total_glucose_conc}')
total_diastolic_bp = len(df.loc[df['diastolic_bp']==0])
print(f'number of Rows missing in diastolic_bp column is {total_diastolic_bp}')
total_insulin = len(df.loc[df['insulin']==0])
print(f'number of Rows missing in insulin column is {total_insulin}')
total_bmi = len(df.loc[df['bmi']==0])
print(f'number of Rows missing in bmi column is {total_bmi}')
total_diab_pred = len(df.loc[df['diab_pred']==0])
print(f'number of Rows missing in diab_pred column is {total_diab_pred}')
total_age = len(df.loc[df['age'] ==0])
print(f'number of rows missing in age is {total_age}')
total_skin = len(df.loc[df['skin'] ==0])
print(f'number of rows missing in skin is {total_skin}')
# Out:
# number of Rows missing in num_preg column is 111
# number of Rows missing in glucose_conc column is 5
# number of Rows missing in diastolic_bp column is 35
# number of Rows missing in insulin column is 374
# number of Rows missing in bmi column is 11
# number of Rows missing in diab_pred column is 0
# number of rows missing in age is 0
# number of rows missing in skin is 227

# %%
from imblearn.over_sampling import SMOTE
from sklearn.impute import SimpleImputer
from collections import Counter
fill_zeros = SimpleImputer(missing_values=0,strategy='mean')
x_train = fill_zeros.fit_transform(x_train)
x_test = fill_zeros.transform(x_test)

# %% [markdown]
# #### Balancing the Data in Equal Proportion

# %%
smote = SMOTE(random_state=42)
x_train_balanced, y_train_balanced = smote.fit_resample(x_train, y_train)
print(f'Balanced class distribution: {Counter(y_train_balanced)}')
# Out:
# Balanced class distribution: Counter({np.int64(0): 349, np.int64(1): 349})

# %% [markdown]
# #### Training the model with different algorithms and choose the best one

# %%
from sklearn.naive_bayes import GaussianNB
nb_model = GaussianNB() #creating object for GaussianNB Class
nb_model.fit(x_train,y_train.ravel()) # Training a model
# Out:
# GaussianNB()

# %%
from sklearn import metrics
nb_predict_model = nb_model.predict(x_train) # Testing a model
print(f'Predicted accuracy { metrics.accuracy_score(y_train,nb_predict_model) }') # Accuracy
# Out:
# Predicted accuracy 0.7541899441340782

# %%
from sklearn import metrics
nb_predict_test = nb_model.predict(x_test)
print(f'Predicted accuracy { metrics.accuracy_score(y_test,nb_predict_test) }')
# Out:
# Predicted accuracy 0.7402597402597403

# %%
print(f'{ metrics.confusion_matrix(y_test,nb_predict_test)}')
# Out:
# [[119  32]
#  [ 28  52]]

# %%
print(f'{ metrics.classification_report(y_test,nb_predict_test)}')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.79      0.80       151
#            1       0.62      0.65      0.63        80
#
#     accuracy                           0.74       231
#    macro avg       0.71      0.72      0.72       231
# weighted avg       0.74      0.74      0.74       231

# %%
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier(random_state=42) 
rf_model.fit(x_train,y_train.ravel())
# Out:
# RandomForestClassifier(random_state=42)

# %%
from sklearn import metrics
rf_predict_model = rf_model.predict(x_train) # Testing a model
print(f'Predicted accuracy { metrics.accuracy_score(y_train,rf_predict_model) }')
# Out:
# Predicted accuracy 1.0

# %%
from sklearn import metrics
rf_predict_test =rf_model.predict(x_test)
print(f'Predicted accuracy { metrics.accuracy_score(y_test,rf_predict_test) }')
# Out:
# Predicted accuracy 0.7532467532467533

# %%
print(f'{ metrics.confusion_matrix(y_test,rf_predict_test)}')
# Out:
# [[121  30]
#  [ 27  53]]

# %%
print(f'{ metrics.classification_report(y_test,rf_predict_test)}')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.80      0.81       151
#            1       0.64      0.66      0.65        80
#
#     accuracy                           0.75       231
#    macro avg       0.73      0.73      0.73       231
# weighted avg       0.76      0.75      0.75       231

# %%
from sklearn.neighbors import KNeighborsClassifier
k_neighbor = KNeighborsClassifier()
k_neighbor.fit(x_train,y_train.ravel())
# Out:
# KNeighborsClassifier()

# %%
 x_pred = k_neighbor.predict(x_test)
 print(f'Accuracy = {metrics.accuracy_score(y_test,x_pred)}')
 print(f'Confusion matrix = \n {metrics.confusion_matrix(y_test,x_pred)}')
# Out:
# Accuracy = 0.7359307359307359
# Confusion matrix =
#  [[119  32]
#  [ 29  51]]

# %%
print(f'{ metrics.classification_report(y_test,x_pred)}')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.79      0.80       151
#            1       0.61      0.64      0.63        80
#
#     accuracy                           0.74       231
#    macro avg       0.71      0.71      0.71       231
# weighted avg       0.74      0.74      0.74       231

# %% [markdown]
# #### After taining with 3 different algorithms found that random forest algorithm giving more accuracy

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(x)
standardized_data = scaler.transform(x)
print(standardized_data)
# Out:
# [[ 0.63994726  0.84832379  0.14964075 ...  0.46849198  1.4259954
#    0.90726993]
#  [-0.84488505 -1.12339636 -0.16054575 ... -0.36506078 -0.19067191
#    0.53090156]
#  [ 1.23388019  1.94372388 -0.26394125 ...  0.60439732 -0.10558415
#   -1.28821221]
#  ...
#  [ 0.3429808   0.00330087  0.14964075 ... -0.68519336 -0.27575966
#    0.15453319]
#  [-0.84488505  0.1597866  -0.47073225 ... -0.37110101  1.17073215
#   -1.28821221]
#  [-0.84488505 -0.8730192   0.04624525 ... -0.47378505 -0.87137393
#    0.65635768]]

# %% [markdown]
# #### Now give input data to the ML model to predict the output

# %%
rf_model_test = rf_model.predict(x_test) # Testing a model
input_data = [6, 148, 72, 0, 33.6, 0.627, 50, 1.3790]
input_data_as_numpy_array = np.asarray(input_data)
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)
std_data = scaler.transform(input_data_reshaped)
print(std_data)
rf_model_test = rf_model.predict(std_data)
print(rf_model_test)
# Out:
# [[ 0.63994726  0.84832379  0.14964075 -0.69289057  0.20401277  0.46849198
#    1.4259954   0.90726993]]
# [0]
